# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Sensitivity Analysis

# %% [markdown]
# ## Vectors

# %%
#Variation
var = ['-25%', '-20%', '-15%', '-10%', '-5%', '0%', '5%', '10%', '15%', '20%', '25%']

#BASE
##NPV
base_capex_npv = [43396326, 38278343, 33160360, 28042376, 22924393,17806410,
                  12688427, 7570444, 2452461, -2665522, -7783505]
base_opex_npv = [24538707, 23192247, 21845788, 20499329, 19152870, 17806410,
                 16459951, 15113492, 13767033, 12420573, 11074114]
base_revenue_npv = [-18967404, -11612641, -4257878, 3096885, 10451648, 17806410,
                    25161173, 32515936, 39870699, 47225462, 54580224]
base_energy_npv = [-17690497, -10591115, -3491734, 3607648, 10707029, 17806410,
                   24905792, 32005173, 39104555, 46203936, 53303318]
##LCOE
base_capex_lcoe = [71.9, 75.5, 79.0, 82.6, 86.1, 89.7, 93.2, 96.8, 100.3, 103.8, 107.4]
base_opex_lcoe = [85.0, 85.9, 86.9, 87.8, 88.7, 89.7, 90.6, 91.5, 92.5, 93.4, 94.3]
base_energy_lcoe = [118.4, 111.2, 104.8, 99.2, 94.2, 89.7, 85.6, 81.8, 78.4, 75.3, 72.4]

#EVAPORATIVE
##NPV
eva_capex_npv = [48154250, 43011523, 37868796, 32726069, 27583342, 22440615,
                 17297888, 12155161, 7012434, 1869707, -3273020]
eva_opex_npv = [26866545, 25981359, 25096173, 24210987, 23325801, 22440615,
                21555430, 20670244, 19785058, 18899872, 18014686]
eva_revenue_npv = [-13309103, -6159159, 990784, 8140728, 15290672, 22440615,
                   29590559, 36740503, 43890446, 51040390, 58190334]
eva_energy_npv = [-12032196, -5137634, 1756928, 8651491, 15546053, 22440615,
                  29335178, 36229740, 43124302, 50018865, 56913427]
##LCOE
eva_capex_lcoe = [67.7, 71.3, 75.0, 78.7, 82.3, 86.0, 89.7, 93.3, 97.0, 100.7, 104.3]
eva_opex_lcoe = [82.8, 83.5, 84.1, 84.7, 85.4, 86.0, 86.6, 87.3, 87.9, 88.5, 89.2]
eva_energy_lcoe = [113.4, 106.6, 100.5, 95.1, 90.3, 86.0, 82.1, 78.5, 75.3, 72.3, 69.5]

#DRY
##NPV
dry_capex_npv = [42695982, 37577999, 32460016, 27342033, 22224050, 17106067,
                 11988084, 6870101, 1752118, -3365865, -8483849]
dry_opex_npv = [21467839, 20595485, 19723130, 18850776, 17978421, 17106067,
                16233712, 15361358, 14489003, 13616648, 12744294]
dry_revenue_npv = [-17122138, -10276497, -3430856, 3414785, 10260426, 17106067,
                   23951708, 30797349, 37642989, 44488630, 51334271]
dry_energy_npv = [-15909388, -9306297, -2703206, 3899885, 10502976, 17106067,
                  23709158, 30312248, 36915339, 43518430, 50121521]
##LCOE
dry_capex_lcoe = [70.2, 74.0, 77.8, 81.6, 85.4, 89.3, 93.1, 96.9, 100.7, 104.5, 108.3]
dry_opex_lcoe = [86.0, 86.7, 87.3, 88.0, 88.6, 89.3, 89.9, 90.6, 91.2, 91.9, 92.5]
dry_energy_lcoe = [117.8, 110.7, 104.4, 98.8, 93.8, 89.3, 85.2, 81.5, 78.1, 75.0, 72.1]

#ONCE THROUGH
##NPV
ot_capex_npv = [53791084, 48564150, 43337216, 38110282, 32883348, 27656414,
                22429480, 17202546, 11975612, 6748678, 1521744]
ot_opex_npv = [32136359, 31240370, 30344381, 29448392, 28552403, 27656414,
               26760425, 25864436, 24968447, 24072458, 23176468]
ot_revenue_npv = [-9872305, -2366561, 5139183, 12644926, 20150670, 27656414,
                  35162158, 42667901, 50173645, 57679389, 65185133]
ot_energy_npv = [-8541382, -1301823, 5937736, 13177295, 20416855, 27656414,
                 34895973, 42135532, 49375091, 56614651, 63854210]
##LCOE
ot_capex_lcoe = [65.5, 69.0, 72.6, 76.1, 79.7, 83.2, 86.8, 90.3, 93.9, 97.4, 101.0]
ot_opex_lcoe = [80.2, 80.8, 81.4, 82.0, 82.6, 83.2, 83.8, 84.4, 85.0, 85.6, 86.3]
ot_energy_lcoe = [109.7, 103.1, 97.3, 92.1, 87.4, 83.2, 79.4, 76.0, 72.8, 69.9, 67.3]

#MED Energy
##NPV
med_capex_npv = [48690321, 43479318, 38268315, 33057312, 27846309, 22635306,
                17424303, 12213300, 7002297, 1791294, -3419708]
med_opex_npv = [28134686, 27034810, 25934934, 24835058, 23735182, 22635306,
                21535430, 20435554, 19335678, 18235803, 17135927]
med_revenue_npv = [424133, 4866368, 9308602, 13750837, 18193072, 22635306,
                   27077541, 31519775, 35962010, 40404245, 44846479]
med_energy_npv = [1466402, 5700183, 9933963, 14167744, 18401525, 22635306,
                  26869087, 31102868, 35336649, 39570430, 43804211]
##LCOE
med_capex_lcoe = [46.1, 52.1, 58.1, 64.0, 70.0, 76.0, 82.0, 88.0, 94.0, 99.9, 105.9]
med_opex_lcoe = [69.7, 71.0, 72.2, 73.5, 74.8, 76.0, 77.3, 78.5, 79.8, 81.1, 82.3]
med_energy_lcoe = [99.8, 93.8, 88.6, 83.9, 79.8, 76.0, 72.6, 69.5, 66.7, 64.1, 61.8]

#MED Water
##NPV
med_wcapex_npv = [24589644, 24198777, 23807909, 23417041, 23026174, 22635306,
                  22244439, 21853571, 21462703, 21071836, 20680968]
med_water_npv = [5678920, 9070198, 12461475, 15852752, 19244029, 22635306,
                    26026583, 29417861, 32809138, 36200415, 39591692]
##LCOE
med_wcapex_lcoe = [73.8, 74.2, 74.7, 75.1, 75.6, 76.0, 76.5, 76.9, 77.4, 77.8, 78.3]
med_water_lcoe = [95.5, 91.6, 87.7, 83.8, 79.9, 76.0, 72.1, 68.2, 64.3, 60.4, 56.5]

# %% [markdown]
# ## BASE

# %%
#Graph
plt.figure(figsize=(16, 8)) #Image Size
plt.plot(var, base_capex_npv, ls= '-', lw= 2, marker= '^', ms= 10,
         label= 'CAPEX')
plt.plot(var, base_opex_npv, ls= '-', lw= 2, marker= 's', ms= 10,
         label= 'OPEX')
plt.plot(var, base_revenue_npv, ls= '-', lw= 2, marker= '*', ms= 10,
         label= 'Revenue')
plt.plot(var, base_energy_npv, ls= '-', lw= 2, marker= 'o', ms= 10,
         label= 'Energy')
#plt.plot([-1, 11], [17806410, 17806410], ls= '--', lw= 2)
plt.yticks(np.arange(-20000000, 70000000, 5000000), fontsize= 16)
plt.xticks(fontsize= 16)
plt.xlabel(r'Variation', fontsize=24)
plt.ylabel(r'NPV [USD]', fontsize=24)
plt.title("Sensitivity Analysis Base", fontsize=28)
plt.xlim(-.3, 10.3)
plt.ylim(-20000000, 66000000)
plt.legend(fontsize= 16)
plt.grid()

#Save figure
plt.savefig('van_base.png', format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## EVAPORATIVE

# %%
#Graph
plt.figure(figsize=(16, 8)) #Image Size
plt.plot(var, eva_capex_npv, ls= '-', lw= 2, marker= '^', ms= 10,
         label= 'CAPEX')
plt.plot(var, eva_opex_npv, ls= '-', lw= 2, marker= 's', ms= 10,
         label= 'OPEX')
plt.plot(var, eva_revenue_npv, ls= '-', lw= 2, marker= '*', ms= 10,
         label= 'Revenue')
plt.plot(var, eva_energy_npv, ls= '-', lw= 2, marker= 'o', ms= 10,
         label= 'Energy')
#plt.plot([-1, 11], [22440615, 22440615], ls= '--', lw= 2)
plt.yticks(np.arange(-20000000, 70000000, 5000000), fontsize= 16)
plt.xticks(fontsize= 16)
plt.xlabel(r'Variation', fontsize=24)
plt.ylabel(r'NPV [USD]', fontsize=24)
plt.title("Sensitivity Analysis Evaporative", fontsize=28)
plt.xlim(-.3, 10.3)
plt.ylim(-20000000, 66000000)
plt.legend(fontsize= 16)
plt.grid()

#Save figure
plt.savefig('van_evap.png', format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## DRY

# %%
#Graph
plt.figure(figsize=(16, 8)) #Image Size
plt.plot(var, dry_capex_npv, ls= '-', lw= 2, marker= '^', ms= 10,
         label= 'CAPEX')
plt.plot(var, dry_opex_npv, ls= '-', lw= 2, marker= 's', ms= 10,
         label= 'OPEX')
plt.plot(var, dry_revenue_npv, ls= '-', lw= 2, marker= '*', ms= 10,
         label= 'Revenue')
plt.plot(var, dry_energy_npv, ls= '-', lw= 2, marker= 'o', ms= 10,
         label= 'Energy')
#plt.plot([-1, 11], [17106067, 17106067], ls= '--', lw= 2)
plt.yticks(np.arange(-20000000, 70000000, 5000000), fontsize= 16)
plt.xticks(fontsize= 16)
plt.xlabel(r'Variation', fontsize=24)
plt.ylabel(r'NPV [USD]', fontsize=24)
plt.title("Sensitivity Analysis Dry", fontsize=28)
plt.xlim(-.3, 10.3)
plt.ylim(-20000000, 66000000)
plt.legend(fontsize= 16)
plt.grid()

#Save figure
plt.savefig('van_dry.png', format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## ONCE THROUGH

# %%
#Graph
plt.figure(figsize=(16, 8)) #Image Size
plt.plot(var, ot_capex_npv, ls= '-', lw= 2, marker= '^', ms= 10,
         label= 'CAPEX')
plt.plot(var, ot_opex_npv, ls= '-', lw= 2, marker= 's', ms= 10,
         label= 'OPEX')
plt.plot(var, ot_revenue_npv, ls= '-', lw= 2, marker= '*', ms= 10,
         label= 'Revenue')
plt.plot(var, ot_energy_npv, ls= '-', lw= 2, marker= 'o', ms= 10,
         label= 'Energy')
#plt.plot([-1, 11], [27656414, 27656414], ls= '--', lw= 2)
plt.yticks(np.arange(-20000000, 70000000, 5000000), fontsize= 16)
plt.xticks(fontsize= 16)
plt.xlabel(r'Variation', fontsize=24)
plt.ylabel(r'NPV [USD]', fontsize=24)
plt.title("Sensitivity Analysis Once Through", fontsize=28)
plt.xlim(-.3, 10.3)
plt.ylim(-20000000, 66000000)
plt.legend(fontsize= 16)
plt.grid()

#Save figure
plt.savefig('van_ot.png', format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## MED ENERGY

# %%
#Graph
plt.figure(figsize=(16, 8)) #Image Size
plt.plot(var, med_capex_npv, ls= '-', lw= 2, marker= '^', ms= 10,
         label= 'CAPEX')
plt.plot(var, med_opex_npv, ls= '-', lw= 2, marker= 's', ms= 10,
         label= 'OPEX')
plt.plot(var, med_revenue_npv, ls= '-', lw= 2, marker= '*', ms= 10,
         label= 'Revenue')
plt.plot(var, med_energy_npv, ls= '-', lw= 2, marker= 'o', ms= 10,
         label= 'Energy')
#plt.plot([-1, 11], [22635306, 22635306], ls= '--', lw= 2)
plt.yticks(np.arange(-20000000, 70000000, 5000000), fontsize= 16)
plt.xticks(fontsize= 16)
plt.xlabel(r'Variation', fontsize=24)
plt.ylabel(r'NPV [USD]', fontsize=24)
plt.title("Sensitivity Analysis MED", fontsize=28)
plt.xlim(-.3, 10.3)
plt.ylim(-20000000, 66000000)
plt.legend(fontsize= 16)
plt.grid()

#Save figure
plt.savefig('van_med.png', format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## MED Water

# %%
#Graph
plt.figure(figsize=(16, 8)) #Image Size
plt.plot(var, med_wcapex_npv, ls= '-', lw= 2, marker= '^', ms= 15,
         label= 'CAPEX MED')
plt.plot(var, med_water_npv, ls= '-', lw= 2, marker= '*', ms= 15,
         label= 'Water Revenue')
#plt.plot([-1, 11], [22635306, 22635306], ls= '--', lw= 2)
plt.yticks(np.arange(0, 45000000, 5000000), fontsize= 16)
plt.xticks(fontsize= 16)
plt.xlabel(r'Variation', fontsize=24)
plt.ylabel(r'NPV [USD]', fontsize=24)
plt.title("Sensitivity Analysis MED System", fontsize=28)
plt.xlim(-.3, 10.3)
plt.legend(fontsize= 16)
plt.grid()

#Save figure
plt.savefig('van_med_water.png', format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# # LCOE

# %% [markdown]
# ## CAPEX

# %%
#Graph
plt.figure(figsize=(16, 8)) #Image Size
plt.plot(var, base_capex_lcoe, ls= '-', lw= 2, marker= '^', ms= 10,
         label= 'Base Case')
plt.plot(var, eva_capex_lcoe, ls= '-', lw= 2, marker= 's', ms= 10,
         label= 'Evaporative Case')
plt.plot(var, dry_capex_lcoe, ls= '-', lw= 2, marker= '*', ms= 10,
         label= 'Dry Case')
plt.plot(var, ot_capex_lcoe, ls= '-', lw= 2, marker= 'o', ms= 10,
         label= 'Once Through Case')
plt.plot(var, med_capex_lcoe, ls= '-', lw= 2, marker= 'P', ms= 10,
         label= 'MED Case \n(CSP CAPEX)')
plt.plot(var, med_wcapex_lcoe, ls= '-', lw= 2, marker= 'D', ms= 10,
         label= 'MED Case \n(MED CAPEX)')
#plt.plot([-1, 11], [17106067, 17106067], ls= '--', lw= 2)
plt.yticks( fontsize= 16)
plt.xticks(fontsize= 16)
plt.xlabel(r'CAPEX Variation [%]', fontsize=24)
plt.ylabel(r'LCOE [USD/MWh]', fontsize=24)
plt.title("LCOE Sensitivity Analysis CAPEX", fontsize=28)
plt.xlim(-.3, 10.3)
#plt.ylim(0, 110)
plt.legend(fontsize= 16)
plt.grid()

#Save figure
plt.savefig('lcoe_capex.png', format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## OPEX

# %%
#Graph
plt.figure(figsize=(16, 8)) #Image Size
plt.plot(var, base_opex_lcoe, ls= '-', lw= 2, marker= '^', ms= 10,
         label= 'Base Case')
plt.plot(var, eva_opex_lcoe, ls= '-', lw= 2, marker= 's', ms= 10,
         label= 'Evaporative Case')
plt.plot(var, dry_opex_lcoe, ls= '-', lw= 2, marker= '*', ms= 10,
         label= 'Dry Case')
plt.plot(var, ot_opex_lcoe, ls= '-', lw= 2, marker= 'o', ms= 10,
         label= 'Once Through Case')
plt.plot(var, med_opex_lcoe, ls= '-', lw= 2, marker= 'P', ms= 10,
         label= 'MED Case')

#plt.plot([-1, 11], [17106067, 17106067], ls= '--', lw= 2)
plt.yticks( fontsize= 16)
plt.xticks(fontsize= 16)
plt.xlabel(r'OPEX Variation [%]', fontsize=24)
plt.ylabel(r'LCOE [USD/MWh]', fontsize=24)
plt.title("LCOE Sensitivity Analysis OPEX", fontsize=28)
plt.xlim(-.3, 10.3)
#plt.ylim(0, 110)
plt.legend(fontsize= 16)
plt.grid()

#Save figure
plt.savefig('lcoe_opex.png', format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Generation

# %%
#Graph
plt.figure(figsize=(16, 8)) #Image Size
plt.plot(var, base_energy_lcoe, ls= '-', lw= 2, marker= '^', ms= 10,
         label= 'Base Case')
plt.plot(var, eva_energy_lcoe, ls= '-', lw= 2, marker= 's', ms= 10,
         label= 'Evaporative Case')
plt.plot(var, dry_energy_lcoe, ls= '-', lw= 2, marker= '*', ms= 10,
         label= 'Dry Case')
plt.plot(var, ot_energy_lcoe, ls= '-', lw= 2, marker= 'o', ms= 10,
         label= 'Once Through Case')
plt.plot(var, med_energy_lcoe, ls= '-', lw= 2, marker= 'P', ms= 10,
         label= 'MED Case \n(Energy generation)')
plt.plot(var, med_water_lcoe, ls= '-', lw= 2, marker= 'P', ms= 10,
         label= 'MED Case \n(Water generation)')

#plt.plot([-1, 11], [17106067, 17106067], ls= '--', lw= 2)
plt.yticks( fontsize= 16)
plt.xticks(fontsize= 16)
plt.xlabel(r'Generation Variation [%]', fontsize=24)
plt.ylabel(r'LCOE [USD/MWh]', fontsize=24)
plt.title("LCOE Sensitivity Analysis Generation", fontsize=28)
plt.xlim(-.3, 10.3)
#plt.ylim(0, 110)
plt.legend(fontsize= 16)
plt.grid()

#Save figure
plt.savefig('lcoe_gen.png', format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# # NPV

# %% [markdown]
# ## CAPEX

# %%
#Graph
plt.figure(figsize=(16, 8)) #Image Size
plt.plot(var, base_capex_npv, ls= '-', lw= 2, marker= '^', ms= 10,
         label= 'Base Case')
plt.plot(var, eva_capex_npv, ls= '-', lw= 2, marker= 's', ms= 10,
         label= 'Evaporative Case')
plt.plot(var, dry_capex_npv, ls= '-', lw= 2, marker= '*', ms= 10,
         label= 'Dry Case')
plt.plot(var, ot_capex_npv, ls= '-', lw= 2, marker= 'o', ms= 10,
         label= 'Once Through Case')
plt.plot(var, med_capex_npv, ls= '-', lw= 2, marker= 'P', ms= 10,
         label= 'MED Case \n(CSP CAPEX)')
plt.plot(var, med_wcapex_npv, ls= '-', lw= 2, marker= 'D', ms= 10,
         label= 'MED Case \n(MED CAPEX)')
#plt.plot([-1, 11], [17106067, 17106067], ls= '--', lw= 2)
plt.yticks( fontsize= 16)
plt.xticks(fontsize= 16)
plt.xlabel(r'CAPEX Variation [%]', fontsize=24)
plt.ylabel(r'NPV [USD]', fontsize=24)
plt.title("NPV Sensitivity Analysis CAPEX", fontsize=28)
plt.xlim(-.3, 10.3)
#plt.ylim(0, 110)
plt.legend(fontsize= 16)
plt.grid()

#Save figure
plt.savefig('npv_capex.png', format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## OPEX

# %%
#Graph
plt.figure(figsize=(16, 8)) #Image Size
plt.plot(var, base_opex_npv, ls= '-', lw= 2, marker= '^', ms= 10,
         label= 'Base Case')
plt.plot(var, eva_opex_npv, ls= '-', lw= 2, marker= 's', ms= 10,
         label= 'Evaporative Case')
plt.plot(var, dry_opex_npv, ls= '-', lw= 2, marker= '*', ms= 10,
         label= 'Dry Case')
plt.plot(var, ot_opex_npv, ls= '-', lw= 2, marker= 'o', ms= 10,
         label= 'Once Through Case')
plt.plot(var, med_opex_npv, ls= '-', lw= 2, marker= 'P', ms= 10,
         label= 'MED Case')

#plt.plot([-1, 11], [17106067, 17106067], ls= '--', lw= 2)
plt.yticks( fontsize= 16)
plt.xticks(fontsize= 16)
plt.xlabel(r'OPEX Variation [%]', fontsize=24)
plt.ylabel(r'NPV [USD]', fontsize=24)
plt.title("NPV Sensitivity Analysis OPEX", fontsize=28)
plt.xlim(-.3, 10.3)
#plt.ylim(0, 110)
plt.legend(fontsize= 16)
plt.grid()

#Save figure
plt.savefig('npv_opex.png', format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## REVENUE

# %%
#Graph
plt.figure(figsize=(16, 8)) #Image Size
plt.plot(var, base_revenue_npv, ls= '-', lw= 2, marker= '^', ms= 10,
         label= 'Base Case')
plt.plot(var, eva_revenue_npv, ls= '-', lw= 2, marker= 's', ms= 10,
         label= 'Evaporative Case')
plt.plot(var, dry_revenue_npv, ls= '-', lw= 2, marker= '*', ms= 10,
         label= 'Dry Case')
plt.plot(var, ot_revenue_npv, ls= '-', lw= 2, marker= 'o', ms= 10,
         label= 'Once Through Case')
plt.plot(var, med_revenue_npv, ls= '-', lw= 2, marker= 'P', ms= 10,
         label= 'MED Case \n(Energy Revenue)')
plt.plot(var, med_water_npv, ls= '-', lw= 2, marker= 'D', ms= 10,
         label= 'MED Case \n(Water Revenue)')

#plt.plot([-1, 11], [17106067, 17106067], ls= '--', lw= 2)
plt.yticks( fontsize= 16)
plt.xticks(fontsize= 16)
plt.xlabel(r'Revenue Variation [%]', fontsize=24)
plt.ylabel(r'NPV [USD]', fontsize=24)
plt.title("NPV Sensitivity Analysis Revenue", fontsize=28)
plt.xlim(-.3, 10.3)
#plt.ylim(0, 110)
plt.legend(fontsize= 16)
plt.grid()

#Save figure
plt.savefig('npv_revenue.png', format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## ENERGY

# %%
#Graph
plt.figure(figsize=(16, 8)) #Image Size
plt.plot(var, base_energy_npv, ls= '-', lw= 2, marker= '^', ms= 10,
         label= 'Base Case')
plt.plot(var, eva_revenue_npv, ls= '-', lw= 2, marker= 's', ms= 10,
         label= 'Evaporative Case')
plt.plot(var, dry_energy_npv, ls= '-', lw= 2, marker= '*', ms= 10,
         label= 'Dry Case')
plt.plot(var, ot_energy_npv, ls= '-', lw= 2, marker= 'o', ms= 10,
         label= 'Once Through Case')
plt.plot(var, med_energy_npv, ls= '-', lw= 2, marker= 'P', ms= 10,
         label= 'MED Case')

#plt.plot([-1, 11], [17106067, 17106067], ls= '--', lw= 2)
plt.yticks( fontsize= 16)
plt.xticks(fontsize= 16)
plt.xlabel(r'Energy Generation Variation [%]', fontsize=24)
plt.ylabel(r'NPV [USD]', fontsize=24)
plt.title("NPV Sensitivity Analysis Energy", fontsize=28)
plt.xlim(-.3, 10.3)
#plt.ylim(0, 110)
plt.legend(fontsize= 16)
plt.grid()

#Save figure
plt.savefig('npv_generation.png', format='png', bbox_inches='tight')
plt.show()
